# %% [markdown]
# ## 2025.11.07 (금) 9주차 수업

# %%
phone_book = {}

# %%
phone_book["강감찬"] = "010-1234-4222"
phone_book["홍길동"] = "010-1234-5678" # dict에 값 넣는 법
phone_book["이순신"] = "010-2133-1321"

# %%
print(phone_book)
# Out:
# {'페이커': '010-1233-4124', '홍길동': '010-1234-5678', '강감찬': '010-1234-4222', '이순신': '010-2133-1321'}

# %%
phone_book = {"페이커" : "010-1233-4124"}

# %%
person_dict = {'Name' : '홍길동', 'Age' : 27 , 'Class' : '초급'}
